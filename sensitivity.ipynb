# %%
from utils import *

# %% [markdown]
# # Numerical data

# %% [markdown]
# ## Single and Two distribution comparison

# %% [markdown]
# ### AVH-no stationary

# %%
#  single distribution
import avh_no_stationary as k_v3
k_clause = k_v3.KClause(is_numeric=True)
k_clause.save_base_dir = '../result/k_clause_v3_single_var/numeric_result'
k_v3_precision_real_single, k_v3_precision_syn_single, k_v3_recall_real_single, k_v3_recall_syn_single = k_clause.parse_result_update()

#  two distribution
k_clause.save_base_dir = '../result/k_clause_v3/numeric_result'
k_v3_precision_real, k_v3_precision_syn, k_v3_recall_real, k_v3_recall_syn = k_clause.parse_result_update()

# %% [markdown]
# ### AVH-with stationar

# %%
#  single distribution
import avh_with_stationary as k_v4

k_clause = k_v4.KClause(is_numeric=True)
k_clause.save_base_dir = '../result/k_clause_v4_single_var/numeric_result'
k_v4_precision_real_single, k_v4_precision_syn_single, k_v4_recall_real_single, k_v4_recall_syn_single = k_clause.parse_result_update()

#  two distribution
k_clause.save_base_dir = '../result/k_clause_v4/numeric_result'
k_v4_precision_real, k_v4_precision_syn, k_v4_recall_real, k_v4_recall_syn = k_clause.parse_result_update()

# %%
# single-only and single+two   
from matplotlib.pyplot import MultipleLocator

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real_single, k_v4_precision_real_single, linestyle='dotted', linewidth=4, label="AVH-single-only", marker='.', markersize=7, c='g')

plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='dashdot', linewidth=4, label="AVH-single+two", marker='.', markersize=7, c='r')

plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.85, 1)
plt.ylim(0.87, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.legend(prop={'size': 20})
plt.tight_layout()
plt.savefig('Numeric: Test on real data.jpg')
plt.show()

# %%
plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v3_recall_real, k_v3_precision_real, linestyle='dotted', linewidth=4, 
         label="AVH-No stationary", marker='.', markersize=7, c='g')

plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='dashdot', linewidth=4, 
         label="AVH-With stationary", marker='.', markersize=7, c='r')

plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.85, 1)
plt.ylim(0.88, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.legend(prop={'size': 20})
plt.tight_layout()
plt.savefig('Numeric: Test on real data.jpg')
plt.show()

# %% [markdown]
# ## vary # of history

# %%
import avh_with_stationary as k_v4

k_clause = k_v4.KClause(is_numeric=True)
k_clause.save_base_dir = '../result/k_clause_v4_7/numeric_result'
k_v4_precision_real_7, k_v4_precision_syn_7, k_v4_recall_real_7, k_v4_recall_syn_7 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_14/numeric_result'
k_v4_precision_real_14, k_v4_precision_syn_14, k_v4_recall_real_14, k_v4_recall_syn_14 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_21/numeric_result'
k_v4_precision_real_21, k_v4_precision_syn_21, k_v4_recall_real_21, k_v4_recall_syn_21 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_28/numeric_result'
k_v4_precision_real_28, k_v4_precision_syn_28, k_v4_recall_real_28, k_v4_recall_syn_28 = k_clause.parse_result_update()

# %%
plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real_7, k_v4_precision_real_7, linestyle='solid', linewidth=4, 
         label="AVH-7 days", marker='.', markersize=7, c='darkorange')

plt.plot(k_v4_recall_real_14, k_v4_precision_real_14, linestyle='dotted', linewidth=4, 
         label="AVH-14 days", marker='.', markersize=7, c='b')

plt.plot(k_v4_recall_real_21, k_v4_precision_real_21, linestyle='dashed',linewidth=4, 
         label="AVH-21 days", marker='.', markersize=7, c='g')

plt.plot(k_v4_recall_real_28, k_v4_precision_real_28, linestyle='dashdot', linewidth=4, 
         label="AVH-28 days", marker='.', markersize=7, c='r')

plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.88, 1)
plt.ylim(0.84, 1)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.legend(prop={'size': 20})
plt.tight_layout()
plt.savefig('Numeric: Vary # of history')
plt.show()

# %% [markdown]
# ## Precisoin Comparison

# %%
import avh_with_stationary as k_v4
from matplotlib.pyplot import MultipleLocator

k_clause = k_v4.KClause(is_numeric=True)
k_clause.save_base_dir = '../result/k_clause_v4/numeric_result'
precision, _, recall_real, recall_syn = k_clause.parse_result_update()

target_precision = np.array(k_clause.budget_list)

precision = 1- np.array(precision[:6])
target_precision = target_precision[:6]


plt.figure(figsize=(5, 10), dpi=80)
plt.scatter(target_precision, precision, c='purple', s=150)

z1 = np.polyfit(target_precision, precision, 1)
p1 = np.poly1d(z1)
x_fit = np.linspace(0, 0.1, 50)
y_fit = p1(x_fit)


plt.plot(x_fit, y_fit, c='purple')

plt.ylabel('Real FPR', fontdict={'size' : 28})
plt.xlabel('Target FPR $\delta$', fontdict={'size' : 28})

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)


plt.yticks(size = 22)
plt.xticks(size = 22)
plt.grid(linestyle=(0, (5, 10)))

plt.show()

# %% [markdown]
# ## clause limit

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=True)

k_clause.save_base_dir = '../result/k_clause_v4/numeric_result'
k_v4_precision_real, k_v4_precision_syn, k_v4_recall_real, k_v4_recall_syn = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_5/numeric_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_5/numeric/'
k_v4_precision_real_5, k_v4_precision_syn_5, k_v4_recall_real_5, k_v4_recall_syn_5 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_4/numeric_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_4/numeric/'
k_v4_precision_real_4, k_v4_precision_syn_4, k_v4_recall_real_4, k_v4_recall_syn_4 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_3/numeric_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_3/numeric/'
k_v4_precision_real_3, k_v4_precision_syn_3, k_v4_recall_real_3, k_v4_recall_syn_3 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_2/numeric_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_2/numeric/'
k_v4_precision_real_2, k_v4_precision_syn_2, k_v4_recall_real_2, k_v4_recall_syn_2 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_1/numeric_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_1/numeric/'
k_v4_precision_real_1, k_v4_precision_syn_1, k_v4_recall_real_1, k_v4_recall_syn_1 = k_clause.parse_result_update()

# %%
plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='solid', linewidth=3, 
         label="AVH", marker='*', markersize=7, c='r')
plt.plot(k_v4_recall_real_5, k_v4_precision_real_5, linestyle='solid', linewidth=3, 
         label="AVH-5-clause", marker='o', markersize=7, c='g')
plt.plot(k_v4_recall_real_4, k_v4_precision_real_4, linestyle='solid', linewidth=3, 
         label="AVH-4-clause", marker='d', markersize=7, c='blue')
plt.plot(k_v4_recall_real_3, k_v4_precision_real_3, linestyle='solid', linewidth=3, 
         label="AVH-3-clause", marker='x', markersize=7, c='y')
plt.plot(k_v4_recall_real_2, k_v4_precision_real_2, linestyle='solid', linewidth=3, 
         label="AVH-2-clause", marker='s', markersize=7, c='purple')
plt.plot(k_v4_recall_real_1, k_v4_precision_real_1, linestyle='solid', linewidth=3, 
         label="AVH-1-clause", marker='1', markersize=7, c='grey')


plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
# plt.xlim(0.6, 1.0)
plt.ylim(0.85, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

plt.legend(loc="lower right", prop={'size': 20})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Synthetical data seperate

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=True)
k_clause.save_base_dir = '../result/k_clause_v4/numeric_result'
precision_schema, recall_schema,\
precision_unit, recall_unit,\
precision_null, recall_null,\
precision_volume, recall_volume,\
precision_distri, recall_distri,\
precision_pert, recall_pert,\
precision_extra_val, recall_extra_val, \
precision_missing_val, recall_missing_val = k_clause.parse_recall_sep()

# %%
# # single-only and single+two   

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(recall_schema, precision_schema, linestyle='dotted', linewidth=4, 
         label="schema change", marker='.', markersize=7, c='g')
plt.plot(recall_unit, precision_unit, linestyle='dotted', linewidth=4, 
         label="unit change", marker='.', markersize=7, c='r')
plt.plot(recall_null, precision_null, linestyle='dotted', linewidth=4, 
         label="increase null", marker='.', markersize=7, c='b')
plt.plot(recall_volume, precision_volume, linestyle='dotted', linewidth=4, 
         label="volume change", marker='.', markersize=7, c='grey')
plt.plot(recall_distri, precision_distri, linestyle='dotted', linewidth=4, 
         label="distribution change", marker='.', markersize=7, c='pink')
plt.plot(recall_pert, precision_pert, linestyle='dotted', linewidth=4, 
         label="character perturbation", marker='.', markersize=7, c='purple')
plt.plot(recall_extra_val, precision_extra_val, linestyle='dotted', linewidth=4, 
         label="character insertion", marker='.', markersize=7, c='orange')
plt.plot(recall_missing_val, precision_missing_val, linestyle='dotted', linewidth=4, 
         label="character deletion", marker='.', markersize=7, c='black')


plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.2, 1)
plt.ylim(0.3, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

# x_major_locator = MultipleLocator(0.04)
# ax = plt.gca()
# ax.xaxis.set_major_locator(x_major_locator)


plt.legend(prop={'size': 20})
plt.tight_layout()
plt.savefig('Category: Test on real data.jpg')
plt.show()

# %% [markdown]
# # Categorical data

# %% [markdown]
# ## Single and Two distribution comparison

# %% [markdown]
# ### AVH-no stationary

# %%
# single distribution
import avh_no_stationary as k_v3
k_clause = k_v3.KClause(is_numeric=False)
k_clause.save_base_dir = '../result/k_clause_v3_single_var/category_result'
k_v3_precision_real_single, k_v3_precision_syn_single, k_v3_recall_real_single, k_v3_recall_syn_single = k_clause.parse_result_update()

# two distribution
k_clause.save_base_dir = '../result/k_clause_v3/category_result'
k_v3_precision_real, k_v3_precision_syn, k_v3_recall_real, k_v3_recall_syn = k_clause.parse_result_update()

# %% [markdown]
# ### AVH-with stationary

# %%
# single distribution
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=False)
k_clause.save_base_dir = '../result/k_clause_v4_single_var/category_result'
k_v4_precision_real_single, k_v4_precision_syn_single, k_v4_recall_real_single, k_v4_recall_syn_single = k_clause.parse_result_update()

# two distribution
k_clause.save_base_dir = '../result/k_clause_v4/category_result0227'
k_v4_precision_real, k_v4_precision_syn, k_v4_recall_real, k_v4_recall_syn = k_clause.parse_result_update()

# %%
# single-only and single+two   

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real_single, k_v4_precision_real_single, linestyle='dotted', linewidth=4, 
         label="AVH-single-only", marker='.', markersize=7, c='g')
plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='dashdot', linewidth=4, 
         label="AVH-single+two", marker='.', markersize=7, c='r')

# plt.title("Category: Test on real data")
plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.92, 1)
plt.ylim(0.84, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

plt.legend(loc="lower left", prop={'size': 20})
plt.tight_layout()
plt.savefig('Category: Test on real data.jpg')
plt.show()

# %%
# single-only and single+two   

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real_single, k_v4_precision_real_single, linestyle='dotted', linewidth=4, 
         label="AVH-single-only", marker='.', markersize=7, c='g')

plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='dashdot', linewidth=4, 
         label="AVH-single+two", marker='.', markersize=7, c='r')

plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.92, 1)
plt.ylim(0.84, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))


plt.legend(loc="lower left", prop={'size': 20})
plt.tight_layout()
plt.savefig('Category: Test on real data.jpg')
plt.show()

# %%
# stationary and no stationary

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v3_recall_real, k_v3_precision_real, linestyle='dotted', linewidth=4, 
         label="AVH-No stationary", marker='.', markersize=7, c='g')
plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='dashdot', linewidth=4, 
         label="AVH-With Stationary", marker='.', markersize=7, c='r')

# plt.title("Category: Test on real data")
plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.92, 1)
plt.ylim(0.88, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)


plt.legend(prop={'size': 20})
plt.tight_layout()
plt.savefig('Category: Test on real data.jpg')
plt.show()

# %% [markdown]
# ## Vary # of history

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=False)
k_clause.save_base_dir = '../result/k_clause_v4_7/category_result'
k_v4_precision_real_7, k_v4_precision_syn_7, k_v4_recall_real_7, k_v4_recall_syn_7 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_14/category_result'
k_v4_precision_real_14, k_v4_precision_syn_14, k_v4_recall_real_14, k_v4_recall_syn_14 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_21/category_result'
k_v4_precision_21, k_v4_recall_real_21, k_v4_recall_syn_21 = k_clause.parse_result()

k_clause.save_base_dir = '../result/k_clause_v4_28/category_result'
k_v4_precision_real_28, k_v4_precision_syn_28, k_v4_recall_real_28, k_v4_recall_syn_28 = k_clause.parse_result_update()

# %%
plt.figure(figsize=(7, 10), dpi=80)

plt.plot(k_v4_recall_real_7, k_v4_precision_real_7, linestyle='solid', linewidth=4, 
         label="AVH-7 days", marker='.', markersize=7, c='darkorange')
plt.plot(k_v4_recall_real_14, k_v4_precision_real_14, linestyle='dotted', linewidth=4, 
         label="AVH-14 days", marker='.', markersize=7, c='b')
plt.plot(k_v4_recall_real_21, k_v4_precision_real_21, linestyle='dashed', linewidth=4, 
         label="AVH-21 days", marker='.', markersize=7, c='g')
plt.plot(k_v4_recall_real_28, k_v4_precision_real_28, linestyle='dashdot', linewidth=4, 
         label="AVH-28 days", marker='.', markersize=7, c='r')


plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.94, 1)
plt.ylim(0.86, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

x_major_locator = MultipleLocator(0.02)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.legend(prop={'size': 20})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Precision comparison

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=False)
k_clause.save_base_dir = '../result/k_clause_v4/category_result'

precision, _, recall_real, recall_syn = k_clause.parse_result_update()

target_precision = np.array(k_clause.budget_list)

precision = 1 - np.array(precision[:6])
target_precision = target_precision[:6]

plt.figure(figsize=(5, 10), dpi=80)
plt.scatter(target_precision, precision, c='purple', s=150)

z1 = np.polyfit(target_precision, precision, 1)
p1 = np.poly1d(z1)
x_fit = np.linspace(0, 0.1, 50)
y_fit = p1(x_fit)
plt.plot(x_fit, y_fit, c='purple')

plt.ylabel('Real FPR', fontdict={'size' : 28})
plt.xlabel('Target FPR $\delta$', fontdict={'size' : 28})

x_major_locator = MultipleLocator(0.04)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)


plt.yticks(size = 22)
plt.xticks(size = 22)
plt.grid(linestyle=(0, (5, 10)))

plt.show()

# %% [markdown]
# ## clause limit

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=False)

k_clause.save_base_dir = '../result/k_clause_v4/category_result'
k_v4_precision_real, k_v4_precision_syn, k_v4_recall_real, k_v4_recall_syn = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_5/category_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_5/category/'
k_v4_precision_real_5, k_v4_precision_syn_5, k_v4_recall_real_5, k_v4_recall_syn_5 = k_clause.parse_result_update()

k_clause.save_bkase_dir = '../result/k_clause_v4_clause_limit_4/category_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_4/category/'
k_v4_precision_real_4, k_v4_precision_syn_4, k_v4_recall_real_4, k_v4_recall_syn_4 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_3/category_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_3/category/'
k_v4_precision_real_3, k_v4_precision_syn_3, k_v4_recall_real_3, k_v4_recall_syn_3 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_2/category_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_2/category/'
k_v4_precision_real_2, k_v4_precision_syn_2, k_v4_recall_real_2, k_v4_recall_syn_2 = k_clause.parse_result_update()

k_clause.save_base_dir = '../result/k_clause_v4_clause_limit_1/category_result'
k_clause.verbose_dir = '../result/k_clause_v4_clause_limit_1/category/'
k_v4_precision_real_1, k_v4_precision_syn_1, k_v4_recall_real_1, k_v4_recall_syn_1 = k_clause.parse_result_update()

# %%
plt.figure(figsize=(7, 10), dpi=80)

# AVH
plt.plot(k_v4_recall_real, k_v4_precision_real, linestyle='solid', linewidth=3, 
         label="AVH", marker='*', markersize=7, c='r')
plt.plot(k_v4_recall_real_5, k_v4_precision_real_5, linestyle='solid', linewidth=3, 
         label="AVH-5-clause", marker='o', markersize=7, c='g')
plt.plot(k_v4_recall_real_4, k_v4_precision_real_4, linestyle='solid', linewidth=3, 
         label="AVH-4-clause", marker='d', markersize=7, c='blue')
plt.plot(k_v4_recall_real_3, k_v4_precision_real_3, linestyle='solid', linewidth=3, 
         label="AVH-3-clause", marker='x', markersize=7, c='y')
plt.plot(k_v4_recall_real_2, k_v4_precision_real_2, linestyle='solid', linewidth=3, 
         label="AVH-2-clause", marker='s', markersize=7, c='purple')
plt.plot(k_v4_recall_real_1, k_v4_precision_real_1, linestyle='solid', linewidth=3, 
         label="AVH-1-clause", marker='1', markersize=7, c='grey')


plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.ylim(0.85, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))
plt.legend(loc='lower left', prop={'size': 20})
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Synthetical data seperate

# %%
import avh_with_stationary as k_v4
k_clause = k_v4.KClause(is_numeric=False)
k_clause.save_base_dir = '../result/k_clause_v4/category_result'
precision_schema, recall_schema,\
    precision_casing, recall_casing,\
    precision_null, recall_null,\
    precision_volume, recall_volume,\
    precision_distri, recall_distri,\
    precision_pert, recall_pert,precision_extra_val, recall_extra_val, \
    precision_missing_val, recall_missing_val, \
    precision_padding, recall_padding = k_clause.parse_recall_sep()   # 111

# %%
# # single-only and single+two   

plt.figure(figsize=(7, 10), dpi=80)

plt.plot(recall_schema, precision_schema, linestyle='dotted', linewidth=4, 
         label="schema change", marker='.', markersize=7, c='g')
plt.plot(recall_casing, precision_casing, linestyle='dotted', linewidth=4, 
         label="casing change", marker='.', markersize=7, c='r')
plt.plot(recall_null, precision_null, linestyle='dotted', linewidth=4, 
         label="increase null", marker='.', markersize=7, c='b')
plt.plot(recall_volume, precision_volume, linestyle='dotted', linewidth=4, 
         label="volume change", marker='.', markersize=7, c='grey')
plt.plot(recall_distri, precision_distri, linestyle='dotted', linewidth=4, 
         label="distribution change", marker='.', markersize=7, c='pink')
plt.plot(recall_pert, precision_pert, linestyle='dotted', linewidth=4, 
         label="character perturbation", marker='.', markersize=7, c='purple')
plt.plot(recall_extra_val, precision_extra_val, linestyle='dotted', linewidth=4, 
         label="character insertion", marker='.', markersize=7, c='orange')
plt.plot(recall_missing_val, precision_missing_val, linestyle='dotted', linewidth=4, 
         label="character deletion", marker='.', markersize=7, c='black')
plt.plot(recall_padding, precision_padding, linestyle='dotted', linewidth=4, 
         label="padding value", marker='.', markersize=7, c='brown')

plt.xlabel('Recall', fontdict={'size' : 30})
plt.ylabel('Precision', fontdict={'size' : 30})
plt.xlim(0.7, 1)
plt.ylim(0.45, 1.0)
plt.yticks(size = 20)
plt.xticks(size = 20)
plt.grid(linestyle=(0, (5, 10)))

plt.legend(prop={'size': 20})
plt.tight_layout()
# plt.savefig('Category: Test on real data.jpg')
plt.show()
